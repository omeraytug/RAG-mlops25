# %%
import lancedb
from dotenv import load_dotenv

load_dotenv()

db = lancedb.connect(uri ="../knowledge_base")

# %%
db["articles"].to_pandas()
# Out:
#   document_name                                           filepath  \
# 0    krabba.txt  /home/apollonspc/RAG-mlops25/rag/src/rag/data/...
# 1     tiger.txt  /home/apollonspc/RAG-mlops25/rag/src/rag/data/...
# 2     kanin.txt  /home/apollonspc/RAG-mlops25/rag/src/rag/data/...
# 3      fisk.txt  /home/apollonspc/RAG-mlops25/rag/src/rag/data/...
# 4     panda.txt  /home/apollonspc/RAG-mlops25/rag/src/rag/data/...
#
#                                              content  \
# 0  \n\n    Uppslagsordet ”Krabba” leder hit. För ...
# 1  Tiger (Panthera tigris) är ett kattdjur som en...
# 2  Harar och kaniner[1] (Leporidae) är en familj ...
# 3  Fiskar (Pisces) är en grupp vattenlevande rygg...
# 4  \n\n    Uppslagsordet ”Panda” leder hit. För a...
#
#                                            embedding
# 0  [0.04360962, -0.009773254, -0.04046631, -0.065...
# 1  [0.022979736, 0.03173828, -0.004386902, -0.050...
# 2  [0.021438599, -0.033203125, 0.040618896, -0.04...
# ...
